# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits

df = pd.read_csv('/Users/admin/Desktop/House_Price_Dataset.csv')
df1= df.drop(['Suburb','Address','Type','Method','Seller','Date','CouncilArea','RegionName'],axis=1,inplace=True)
data = df.dropna(axis = 0, inplace=False)

# %%
data.head()
# Out:
#     Rooms      Price  Distance  Postcode  Rooms2  Bathroom  Car  Landsize  \
# 2       2  1035000.0       2.5    3067.0     2.0       1.0  0.0     156.0
# 4       3  1465000.0       2.5    3067.0     3.0       2.0  0.0     134.0
# 6       4  1600000.0       2.5    3067.0     3.0       1.0  2.0     120.0
# 11      3  1876000.0       2.5    3067.0     4.0       2.0  0.0     245.0
# 14      2  1636000.0       2.5    3067.0     2.0       1.0  2.0     256.0
#
#     BuildingArea  YearBuilt  Latitude  Longitude  PropertyCount
# 2           79.0     1900.0  -37.8079   144.9934         4019.0
# 4          150.0     1900.0  -37.8093   144.9944         4019.0
# 6          142.0     2014.0  -37.8072   144.9941         4019.0
# 11         210.0     1910.0  -37.8024   144.9993         4019.0
# 14         107.0     1890.0  -37.8060   144.9954         4019.0

# %%
data.describe()
# Out:
#              Rooms         Price     Distance     Postcode       Rooms2  \
# count  8887.000000  8.887000e+03  8887.000000  8887.000000  8887.000000
# mean      3.098909  1.092902e+06    11.199887  3111.662653     3.078204
# std       0.963786  6.793819e+05     6.813402   112.614268     0.966269
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.410000e+05     6.400000  3044.000000     2.000000
# 50%       3.000000  9.000000e+05    10.200000  3084.000000     3.000000
# 75%       4.000000  1.345000e+06    13.900000  3150.000000     4.000000
# max      12.000000  9.000000e+06    47.400000  3977.000000    12.000000
#
#           Bathroom          Car      Landsize  BuildingArea    YearBuilt  \
# count  8887.000000  8887.000000   8887.000000   8887.000000  8887.000000
# mean      1.646450     1.692247    523.480365    149.309477  1965.753348
# std       0.721611     0.975464   1061.324228     87.925580    37.040876
# ...

# %%
data['Rooms'].value_counts().plot(kind='bar')
plt.title('number of room')
plt.xlabel('rooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=data.Latitude.values, y=data.Longitude.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
sns.despine
# Out:
# /Users/admin/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data.BuildingArea,data.Price)
plt.title("Price vs Square Feet")
plt.xlim(0, 1200)
# Out:
# (0, 1200)

# %%
plt.scatter(data.Longitude, data.Price)
plt.title("Price vs Location of the area")
plt.xlabel('Longitude')
plt.ylabel("Price")
plt.title("Longitude vs Price")
# Out:
# Text(0.5, 1.0, 'Longitude vs Price')

# %%
plt.scatter(data.Latitude, data.Price)
plt.title("Price vs Location of the area")
plt.xlabel('Latitude')
plt.ylabel("Price")
plt.title("Latitude vs Price")
# Out:
# Text(0.5, 1.0, 'Latitude vs Price')

# %%
plt.scatter(data.Distance, data.Price)
plt.title("Price vs Distance")
plt.xlabel('Distance')
plt.ylabel("Price")
plt.title("Distance vs Price")
# Out:
# Text(0.5, 1.0, 'Distance vs Price')

# %%
plt.scatter(data.Postcode,data.Price)
plt.title("Which is the pricey location by postcode?")
# Out:
# Text(0.5, 1.0, 'Which is the pricey location by postcode?')

# %%
plt.scatter(data.Rooms,data.Price)
plt.title("Rooms and Price ")
plt.xlabel("Rooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data.Bathroom,data.Price)
plt.title("Bathrooms and Price ")
plt.xlabel("Bathrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data.YearBuilt,data.Price)
plt.title("YearBulit and Price ")
plt.xlabel("YearBuilt")
plt.ylabel("Price")
plt.xlim(1825,2019)
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
corr = df.select_dtypes(include = ['float64', 'int64']).iloc[:,1:].corr()
#fig = plt.figure()
sns.set(font_scale=1)  
sns.heatmap(corr, vmax=1, square=True)

# %%
corr_list = corr['Price'].sort_values(axis=0,ascending=False).iloc[1:]
corr_list

# %%
plt.figure(figsize=(18,8))
for i in range(6):
    ii = '23'+str(i+1)
    plt.subplot(ii)
    feature = corr_list.index.values[i]
    plt.scatter(df[feature], df['SalePrice'], facecolors='none',edgecolors='k',s = 75)
    sns.regplot(x = feature, y = 'SalePrice', data = df,scatter=False, color = 'Blue')
    ax=plt.gca() 
    ax.set_ylim([0,800000])
